# %% [markdown]
# <a href="https://colab.research.google.com/github/verlisaaml28/bioinformatika/blob/main/Praktikum_GitHub_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Praktikum GitHub untuk Google Colab
# Sinkronisasi rutin: **clone → edit → commit → push**
#
#
# **Tujuan**
# - Memahami GitHub sebagai jejak kerja, portofolio, dan backup.
# - Mampu melakukan *commit → push* rutin dari Google Colab.
# - Mampu menarik perubahan terbaru (*pull*) saat lanjut kerja.
#
# > Catatan: notebook ini sengaja “praktikum-minded”: banyak sel terminal (`!...`) yang dipakai langsung di Colab.

# %% [markdown]
# halo halo

# %% [markdown]
# ## 1) Konsep Kunci (super ringkas)
# - **Repo**: rumah proyek.
# - **Commit**: snapshot perubahan.
# - **Branch**: jalur pengembangan (umumnya `main`).
# - **Remote**: repo di GitHub.
# - **Push/Pull**: kirim/ambil perubahan.
# - **.gitignore**: daftar file yang tidak ikut versioning.

# %% [markdown]
# ## 2) Aturan Praktikum (kebiasaan)
# - Sinkronisasi dilakukan **minimal 1× setiap sesi**.
# - Commit kecil, sering: setiap ada kemajuan bermakna (fungsi selesai, bug fix, analisis selesai).
# - Hindari unggah data besar & data sensitif.

# %% [markdown]
# ## 3) Set variabel repo (wajib diisi)
# Isi nilai berikut, lalu jalankan selnya.

# %%
# === GANTI SESUAI AKUN/REPO ===
GITHUB_USERNAME = "username"
REPO_NAME = "praktikum-python-BR"
REPO_URL = f"https://github.com/username/praktikum-python-2026.git"

# Folder kerja di Colab (opsional)
WORKDIR = "/content"

print("REPO_URL =", REPO_URL)

# %% [markdown]
# ## 4) Clone repo ke Colab
# Jalankan sel berikut untuk menyalin repo dari GitHub ke runtime Colab.

# %%
import os
os.chdir(WORKDIR)
# !pwd

# Clone (kalau sudah pernah clone dan folder ada, hapus folder atau pakai pull)
# !git clone {REPO_URL}

# %% [markdown]
# ## 5) Masuk folder repo

# %%
import os
os.chdir(f"{WORKDIR}/{REPO_NAME}")
# !pwd
# !ls -la

# %% [markdown]
# ## 6) Buat struktur folder minimal (sekali saja)
# Disarankan untuk proyek praktikum.

# %%
import os
for d in ["data", "src", "notebooks", "outputs"]:
    os.makedirs(d, exist_ok=True)

# !ls -la

# %% [markdown]
# ## 7) Simpan notebook ke dalam repo
# Cara praktis: simpan salinan notebook ini ke folder `notebooks/`.
#
# - Colab: `File → Save a copy in GitHub` (opsional) **atau**
# - `File → Save a copy in Drive` lalu unggah manual ke repo **atau**
# - Simpan notebook di runtime, lalu `git add`.

# %% [markdown]
# ## 8) Buat / update `.gitignore`
# Agar file sampah tidak ikut repo.

# %%
# Buat .gitignore sederhana (aman untuk praktikum)
gitignore_text = """__pycache__/
.ipynb_checkpoints/
*.pyc
*.pyo
*.pyd
.DS_Store
"""

with open(".gitignore", "w", encoding="utf-8") as f:
    f.write(gitignore_text)

print("Isi .gitignore:")
# !cat .gitignore

# %% [markdown]
# ## 9) Buat / update `README.md`
# Template ringkas untuk repo praktikum.

# %%
readme = f"""# {REPO_NAME}

## Ringkasan
Repo praktikum sinkronisasi Google Colab ↔ GitHub.

## Cara menjalankan
1. Buka notebook di folder `notebooks/`
2. Jalankan sel dari atas ke bawah

## Struktur folder
- `src/` : kode .py (fungsi/kelas)
- `notebooks/` : notebook praktikum
- `data/` : data kecil (hindari data besar/sensitif)
- `outputs/` : output penting (pilih yang perlu saja)

## Catatan data
Data besar disimpan terpisah (misal Google Drive); repo menyimpan skrip + instruksi.
"""

with open("README.md", "w", encoding="utf-8") as f:
    f.write(readme)

# !sed -n '1,120p' README.md

# %% [markdown]
# ## 10) Cek perubahan (status)
# Sel ini dipakai sebelum commit, supaya tahu apa yang berubah.

# %%
# !git status

# %% [markdown]
# [[*menggeser fokus ke “commit message”*]]
# ## 11) Add & Commit
# Pilih pesan commit yang informatif, misal:
# - `add: struktur folder + gitignore`
# - `docs: tambah README`
# - `fix: perbaiki fungsi X`

# %%
# !git config user.email "brian_rhardi@yahoo.co.id"
# !git config user.name "bhree"

# %%
# GANTI pesan commit
COMMIT_MESSAGE = "add: inisialisasi repo praktikum delete token"

# !git add .
# !git commit -m "{COMMIT_MESSAGE}"

# %% [markdown]
# ## 12) Push ke GitHub (autentikasi)
# Saat `git push`, GitHub bisa meminta kredensial.
#
# **Kaidah keamanan**
# - Token (PAT) diperlakukan seperti password.
# - Jangan menulis token sebagai teks permanen di notebook.
# - Bila token bocor: revoke dan buat token baru.
#
# > Di banyak kasus, prompt login akan muncul saat push. Tempel token ketika diminta “password”.

# %%
#git and token
# !git remote set-url origin https://bhree:token_xxxxxx@github.com/bhree/praktikum-python-BR.git

# %%
# !git push

# %% [markdown]
# ## 13) Pull perubahan terbaru (saat lanjut kerja)
# Dipakai jika repo di GitHub sudah lebih baru (misal ada edit dari perangkat lain).

# %%
# !git config pull.rebase false

# %%
# !git pull

# %% [markdown]
# ## 14) Troubleshooting Cepat
# - **authentication failed** → token salah/kadaluarsa.
# - **rejected (non-fast-forward)** → jalankan `git pull` dulu, lalu push.
# - **merge conflict notebook** → hindari edit notebook yang sama dari dua tempat sekaligus; simpan versi penting lalu rapikan manual.

# %% [markdown]
# [[*memberi tugas kecil yang terasa nyata*]]
# ## 15) Tugas Praktikum (minimal)
# - Repo sudah dibuat + ada `README.md`
# - Ada 1 notebook di `notebooks/`
# - Ada **≥ 3 commit** berbeda sepanjang praktikum (bukan sekali upload di akhir)
# - Tidak ada data sensitif/kredensial di repo

# %% [markdown]
# [[*menutup notebook seperti menutup buku log lab*]]
# —
# Dibuat: 2026-03-02 04:03:47
